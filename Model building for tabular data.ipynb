# %%
import torch
from simple_nn_model import SimpleNN

from torchview import draw_graph
from torchsummary import summary

# %%
batch_size = 16
input_size = 430  # Adjust based on the number of features in your tabular data

# %%
model = SimpleNN(input_size)

# %%
model_graph = draw_graph(model, input_size=(batch_size,input_size), device='meta', expand_nested=True)
model_graph.visual_graph.attr(size='"5,5!"')
model_graph.visual_graph

# %%
model_graph.visual_graph.render(filename='img/insider_threats_model_arch')
# Out:
# 'img/insider_threats_model_arch.pdf'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
summary(SimpleNN(input_size).to(device), (input_size,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Linear-1                  [-1, 100]          43,100
#        BatchNorm1d-2                  [-1, 100]             200
#          LeakyReLU-3                  [-1, 100]               0
#            Dropout-4                  [-1, 100]               0
#             Linear-5                  [-1, 100]          10,100
#        BatchNorm1d-6                  [-1, 100]             200
#          LeakyReLU-7                  [-1, 100]               0
#            Dropout-8                  [-1, 100]               0
#             Linear-9                  [-1, 100]          10,100
#       BatchNorm1d-10                  [-1, 100]             200
#         LeakyReLU-11                  [-1, 100]               0
#           Dropout-12                  [-1, 100]               0
#            Linear-13                  [-1, 100]          10,100
# ...
